# %% [markdown]
# # Ejercicio 1 evaluativo:

# %%
angulo = int(input("Ingrese el angulo en grados"))
angulo_radianes = angulo * (3.14/180)
print(f"El angulo en radianes es: {angulo_radianes}")
# Out:
# Ingrese el angulo en grados 35
# El angulo en radianes es: 0.6105555555555556

# %% [markdown]
# # Ejercicio 2 evaluativo:

# %%
numero = int(input("Ingrese un numero de cuatro dígitos: "))
for digito in str(numero):
    print(digito)
# Out:
# Ingrese un numero de cuatro dígitos:  2399
# 2
# 3
# 9
# 9

# %% [markdown]
# str convierte un valor numérico (1234) en su representación de caracteres ("1234").
# Una cadena se puede recorrer elemento por elemento con un for.
# En cada iteración obtienes un digito

# %%
numero = input("Ingrese un numero de cuatro digitos: ")
indice = 0
while indice < len(numero):
    print(numero[indice])
    indice+=1
# Out:
# Ingrese un numero de cuatro digitos:  234
# 2
# 3
# 4

# %%
type(numero)
# Out:
# str

# %% [markdown]
# Aqui funciona con un while, y es porque numero también es un str que puede recorrerse

# %%
numeros = input("Ingrese un numero de cuatro digitos: ")
for numero in numeros:  # Para [variable] en [lista]
    print(numero)
# Out:
# Ingrese un numero de cuatro digitos:  245
# 2
# 4
# 5

# %% [markdown]
# Aqui funciona con un for, y es porque numero también es un str que puede recorrerse

# %%
numeros = int(input("Ingrese un numero de cuatro digitos: "))
for numero in numeros:  # Para [variable] en [lista]
    print(numero)
# Out:
# Ingrese un numero de cuatro digitos:  245
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-461efb9cede1> in <module>
#       1 numeros = int(input("Ingrese un numero de cuatro digitos: "))
# ----> 2 for numero in numeros:  # Para [variable] en [lista]
#       3     print(numero)
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# Si dejamos a "numero/numeros" como int, nos indica que no pueden iterarse

# %% [markdown]
# # Ejercicio 3 evaluativo:

# %% [markdown]
# Elabore un programa en Python que lea un área en hectáreas y la convierta en centímetros cuadrados y muestre el resultado con un mensaje bien explicativo.

# %%
area = int(input("Ingrese el area en hectáreas: "))
area_cm2 = area * (10**8)
print(f"El área en hectáreas ingresada es de ", area, " que equivale a ", area_cm2, "cm cuadrados")
# Out:
# Ingrese el area en hectáreas:  2
# El área en hectáreas ingresada es de  2  que equivale a  200000000 cm cuadrados

# %%
hectarea = float(input("Ingrese el valor de la hectárea: "))
centimetros_cuadrados = hectarea * 1E+8
print(f" {hectarea} hectárea es igual a {centimetros_cuadrados} centimetros cuadrados.")
# Out:
# Ingrese el valor de la hectárea:  2
#  2.0 hectárea es igual a 200000000.0 centimetros cuadrados.

# %% [markdown]
# # Ejercicio 4 evaluativo:

# %% [markdown]
# Elabore programa en Python que imprima la suma de los números enteros de -200 hasta 600

# %%
suma = 0
for i in range(-200,600):
    suma = suma + i
    print(suma)
# Out:
# -200
# -399
# -597
# -794
# -990
# -1185
# -1379
# -1572
# -1764
# -1955
# -2145
# -2334
# -2522
# -2709
# -2895
# -3080
# -3264
# -3447
# -3629
# -3810
# -3990
# -4169
# -4347
# -4524
# -4700
# -4875
# -5049
# -5222
# -5394
# -5565
# -5735
# -5904
# -6072
# -6239
# -6405
# -6570
# -6734
# -6897
# -7059
# -7220
# -7380
# -7539
# -7697
# -7854
# -8010
# -8165
# -8319
# -8472
# -8624
# -8775
# -8925
# -9074
# -9222
# -9369
# -9515
# -9660
# -9804
# -9947
# -10089
# -10230
# -10370
# -10509
# -10647
# -10784
# -10920
# -11055
# -11189
# -11322
# -11454
# -11585
# -11715
# -11844
# -11972
# -12099
# -12225
# -12350
# -12474
# -12597
# -12719
# -12840
# -12960
# -13079
# -13197
# -13314
# -13430
# -13545
# -13659
# -13772
# -13884
# -13995
# -14105
# -14214
# -14322
# -14429
# -14535
# -14640
# -14744
# -14847
# -14949
# -15050
# -15150
# -15249
# -15347
# -15444
# -15540
# -15635
# -15729
# -15822
# -15914
# -16005
# -16095
# -16184
# -16272
# -16359
# -16445
# -16530
# -16614
# -16697
# ...

# %% [markdown]
# Esta forma me saca las sumas, pero de manera consecutiva, quizá preguntan es por el total
#
# **Suma de rango de numeros**

# %%
suma = 0
while True:
numero = range(-200,600)

# %%
for numbers in range(-200, 600):
    star = -200 + 1
    end = 600 - 1
result = star + end
print(result)
# Out:
# 400
